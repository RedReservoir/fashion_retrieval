# %%
import os
import pathlib
import math

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import src.utils.time
import src.utils.dict
import src.utils.comps
import src.utils.module
import src.utils.json

import src.comps.heads_pyramid_2

# %%
tab20_color_list =\
    [mpl.colormaps["tab20"](x) for x in (np.linspace(0, 1-1/20, 20) + 1/(2*20))[0::2]] +\
    [mpl.colormaps["tab20"](x) for x in (np.linspace(0, 1-1/20, 20) + 1/(2*20))[1::2]]

# %% [markdown]
# ---

# %%
exp_data_all = {}

# %%
data_subdir_name = "ret_train"
backbone_name = "convnext_t"
exp_name_list = [
    "test_002"
]
    
#

if data_subdir_name not in exp_data_all.keys(): exp_data_all[data_subdir_name] = {}
exp_data_all[data_subdir_name][backbone_name] = {}

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", data_subdir_name, backbone_name)

for exp_name in exp_name_list:

    exp_filename = os.path.join(exp_dirname, exp_name, "exp_data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    exp_data_all[data_subdir_name][backbone_name][exp_name] = exp_data

# %%
data_subdir_name = "ret_train_old_smpl"
backbone_name = "convnext_t_s1"
exp_name_list =\
    ["exp_{:03d}".format(exp_idx) for exp_idx in [0, 6]]

#

if data_subdir_name not in exp_data_all.keys(): exp_data_all[data_subdir_name] = {}
exp_data_all[data_subdir_name][backbone_name] = {}

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", data_subdir_name, backbone_name)

for exp_name in exp_name_list:

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_1__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    exp_data_all[data_subdir_name][backbone_name][exp_name] = exp_data

# %%
data_subdir_name = "ret_train_old_smpl"
backbone_name = "convnext_t_s2"
exp_name_list =\
    ["exp_{:03d}".format(exp_idx) for exp_idx in [0, 6]]

#

if data_subdir_name not in exp_data_all.keys(): exp_data_all[data_subdir_name] = {}
exp_data_all[data_subdir_name][backbone_name] = {}

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", data_subdir_name, backbone_name)

for exp_name in exp_name_list:

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_2__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    exp_data_all[data_subdir_name][backbone_name][exp_name] = exp_data

# %%
data_subdir_name = "ret_train_old_smpl"
backbone_name = "swint_v2_t_s1"
exp_name_list =\
    ["exp_{:03d}".format(exp_idx) for exp_idx in [14]]
    
#

if data_subdir_name not in exp_data_all.keys(): exp_data_all[data_subdir_name] = {}
exp_data_all[data_subdir_name][backbone_name] = {}

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", data_subdir_name, backbone_name)

for exp_name in exp_name_list:

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_1__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    exp_data_all[data_subdir_name][backbone_name][exp_name] = exp_data

# %%
data_subdir_name = "ret_train_old_smpl"
backbone_name = "swint_v2_t_s2"
exp_name_list =\
    ["run_{:03d}".format(exp_idx) for exp_idx in [2]]
    
#

if data_subdir_name not in exp_data_all.keys(): exp_data_all[data_subdir_name] = {}
exp_data_all[data_subdir_name][backbone_name] = {}

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", data_subdir_name, backbone_name)

for exp_name in exp_name_list:

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_2__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    exp_data_all[data_subdir_name][backbone_name][exp_name] = exp_data

# %%
data_subdir_name = "ret_train_old_smpl_2"
backbone_name = "convnext_t_s1"
exp_name_list =\
    ["glam_000_exp_{:03d}".format(exp_idx) for exp_idx in [0, 1, 2, 3, 4, 5, 6]]

#

if data_subdir_name not in exp_data_all.keys(): exp_data_all[data_subdir_name] = {}
exp_data_all[data_subdir_name][backbone_name] = {}

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", data_subdir_name, backbone_name)

for exp_name in exp_name_list:

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_1__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    exp_data_all[data_subdir_name][backbone_name][exp_name] = exp_data

# %%
data_subdir_name = "ret_train_old_smpl_2"
backbone_name = "convnext_t_s2"
exp_name_list =\
    ["glam_000_exp_{:03d}".format(exp_idx) for exp_idx in [0, 1, 2, 3, 4, 5, 6, 7]]

#

if data_subdir_name not in exp_data_all.keys(): exp_data_all[data_subdir_name] = {}
exp_data_all[data_subdir_name][backbone_name] = {}

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", data_subdir_name, backbone_name)

for exp_name in exp_name_list:

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_2__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    exp_data_all[data_subdir_name][backbone_name][exp_name] = exp_data

# %%
exp_data_all.keys()
# Out:
# dict_keys(['ret_train', 'ret_train_old_smpl', 'ret_train_old_smpl_2'])

# %%
exp_data_all["ret_train"].keys()
# Out:
# dict_keys(['convnext_t'])

# %%
exp_data_all["ret_train_old_smpl"].keys()
# Out:
# dict_keys(['convnext_t_s1', 'convnext_t_s2', 'swint_v2_t_s1', 'swint_v2_t_s2'])

# %%
exp_data_all["ret_train_old_smpl_2"].keys()
# Out:
# dict_keys(['convnext_t_s1', 'convnext_t_s2'])

# %%
exp_data_all["ret_train_old_smpl_2"]["convnext_t_s1"].keys()
# Out:
# dict_keys(['glam_000_exp_000', 'glam_000_exp_001', 'glam_000_exp_002', 'glam_000_exp_003', 'glam_000_exp_004', 'glam_000_exp_005', 'glam_000_exp_006'])

# %%
exp_data_all["ret_train_old_smpl_2"]["convnext_t_s2"].keys()
# Out:
# dict_keys(['glam_000_exp_000', 'glam_000_exp_001', 'glam_000_exp_002', 'glam_000_exp_003', 'glam_000_exp_004', 'glam_000_exp_005', 'glam_000_exp_006', 'glam_000_exp_007'])

# %% [markdown]
# ---

# %%
def plot_losses(
    exp_name_list,
    exp_data_list,
    head_idx,
    num_epochs=5
):

    fig, axs = plt.subplots(nrows=2, figsize=(20, 12))

    # ConvNeXt-T Baseline

    exp_data = exp_data_all["ret_train"]["convnext_t"]["test_002"]

    train_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["train_mean_loss_list"]][:num_epochs]
    val_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["val_mean_loss_list"]][:num_epochs]

    finished = exp_data["results"]["stage_1"]["finished"]

    label_lines = []
    label_lines.append("Stage 1 Baseline")
    label_lines.append("ConvNeXt-T")
    label = "\n".join(label_lines)

    color = [0.66, 0.66, 0.66]

    axs[0].plot(range(1, len(train_loss_list) + 1), train_loss_list, label=label, color=color, marker=".", linestyle="--")
    axs[1].plot(range(1, len(val_loss_list) + 1), val_loss_list, label=label, color=color, marker=".", linestyle="--")

    # ConvNeXt-T + Fusion Baseline (0)

    exp_data = exp_data_all["ret_train_old_smpl"]["convnext_t_s1"]["exp_000"]

    train_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["train_mean_loss_list"]][:num_epochs]
    val_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["val_mean_loss_list"]][:num_epochs]

    finished = exp_data["results"]["stage_1"]["finished"]

    label_lines = []
    label_lines.append("Stage 1 Baseline")
    label_lines.append("ConvNeXt-T + Fusion Head (BottomUp)")
    label = "\n".join(label_lines)

    color = [0.33, 0.33, 0.33]

    axs[0].plot(range(1, len(train_loss_list) + 1), train_loss_list, label=label, color=color, marker=".", linestyle="--")
    axs[1].plot(range(1, len(val_loss_list) + 1), val_loss_list, label=label, color=color, marker=".", linestyle="--")

    # ConvNeXt-T + Fusion Baseline (6)

    exp_data = exp_data_all["ret_train_old_smpl"]["convnext_t_s1"]["exp_006"]

    train_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["train_mean_loss_list"]][:num_epochs]
    val_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["val_mean_loss_list"]][:num_epochs]

    finished = exp_data["results"]["stage_1"]["finished"]

    label_lines = []
    label_lines.append("Stage 1 Baseline")
    label_lines.append("ConvNeXt-T + Fusion Head (TopDown)")
    label = "\n".join(label_lines)

    color = [0.33, 0.33, 0.33]

    axs[0].plot(range(1, len(train_loss_list) + 1), train_loss_list, label=label, color=color, marker=".", linestyle="--")
    axs[1].plot(range(1, len(val_loss_list) + 1), val_loss_list, label=label, color=color, marker=".", linestyle="--")

    # ConvNeXt-T     # SwinTV2-T Baseline

    exp_data = exp_data_all["ret_train_old_smpl"]["swint_v2_t_s1"]["exp_014"]

    train_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["train_mean_loss_list"]][:num_epochs]
    val_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["val_mean_loss_list"]][:num_epochs]

    finished = exp_data["results"]["stage_1"]["finished"]

    label_lines = []
    label_lines.append("Stage 1 Baseline")
    label_lines.append("SwinTransformerV2-T")
    label = "\n".join(label_lines)

    color = [0, 0, 0]

    axs[0].plot(range(1, len(train_loss_list) + 1), train_loss_list, label=label, color="black", marker=".", linestyle="--")
    axs[1].plot(range(1, len(val_loss_list) + 1), val_loss_list, label=label, color="black", marker=".", linestyle="--")

    # Experiments from ret_train_old_smpl_2/convnext_t_s1 with GLAM

    for exp_name, exp_data in zip(exp_name_list, exp_data_list):

        # Load data

        train_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["train_mean_loss_list"]]
        val_loss_list = [sum(l) for l in exp_data["results"]["stage_1"]["val_mean_loss_list"]]

        train_loss_list = train_loss_list[:min(num_epochs, len(train_loss_list))]
        val_loss_list = val_loss_list[:min(num_epochs, len(val_loss_list))]

        finished = exp_data["results"]["stage_1"]["finished"]
        base_lr = exp_data["settings"]["stage_1"]["optimizer"]["lr"]
        gamma = gamma = exp_data["settings"]["stage_1"]["scheduler"]["gamma"]

        head_class = exp_data["settings"]["head"]["class"]

        # Title

        title_lines = []    
        title_lines.append("{:s}".format(exp_name))
        if math.isnan(train_loss_list[-1]):
            title_lines[-1] += " | NAN"
        elif not finished:
            title_lines[-1] += " | Unifinished"
        title_lines.append("ConvNeXt-T")
        title_lines.append("{:2s}".format(
            head_class
        ))
        title_lines.append("LR: {:s}".format(np.format_float_scientific(base_lr, min_digits=2, exp_digits=1)))
        title_lines.append("GAM: {:.2f}".format(gamma))

        label = "\n".join(title_lines)

        # Early Stopping Mockup

        last_loss = float("inf")
        early_stop_counter = 0
        idx = 0
        while early_stop_counter < 5 and idx < len(val_loss_list):
            if val_loss_list[idx] < last_loss - 1e-10:
                last_loss = val_loss_list[idx]
                early_stop_counter = 0
            else:
                early_stop_counter += 1
            idx += 1

        train_loss_list = train_loss_list[:idx]
        val_loss_list = val_loss_list[:idx]

        # Plot

        axs[0].plot(range(1, len(train_loss_list) + 1), train_loss_list, label=label, marker=".")
        axs[1].plot(range(1, len(val_loss_list) + 1), val_loss_list, label=label, marker=".")

    # Generic settings

    axs[0].set_yscale("log")
    axs[1].set_yscale("log")

    axs[0].grid()
    axs[1].grid()

    axs[0].set_title("Train loss")
    axs[1].set_title("Val loss")

    #plt.suptitle("Head {:d}".format(head_idx))
    plt.legend(prop={'family': 'monospace', "size": 13}, bbox_to_anchor=(1.05, 2.00))
    plt.show()

# %%
exp_name_list = ["glam_000_exp_{:03d}".format(exp_idx) for exp_idx in [0, 1, 2, 3, 4, 5, 6]]
exp_data_list = [exp_data_all["ret_train_old_smpl_2"]["convnext_t_s1"][key] for key in exp_name_list]

#

plot_losses(
    exp_name_list,
    exp_data_list,
    None,
    num_epochs=30
)

# %%
def plot_losses_2(
    exp_name_list_1,
    exp_name_list_2,
    exp_data_list_1,
    exp_data_list_2
):

    fig, axs = plt.subplots(nrows=2, figsize=(20, 12))

    # ConvNeXt-T Baseline S1 + S2

    exp_data = exp_data_all["ret_train"]["convnext_t"]["test_002"]

    train_loss_list_1 = [sum(l) for l in exp_data["results"]["stage_1"]["train_mean_loss_list"]]
    val_loss_list_1 = [sum(l) for l in exp_data["results"]["stage_1"]["val_mean_loss_list"]]

    train_loss_list_2 = [sum(l) for l in exp_data["results"]["stage_2"]["train_mean_loss_list"]]
    val_loss_list_2 = [sum(l) for l in exp_data["results"]["stage_2"]["val_mean_loss_list"]]

    train_loss_list = train_loss_list_1 + train_loss_list_2
    val_loss_list = val_loss_list_1 + val_loss_list_2

    epoch_num_list = [idx + 1 for idx in range(len(train_loss_list_1))] + [idx + 31 for idx in range(len(train_loss_list_2))]


    label_lines = []
    label_lines.append("Stage 1+2 Baseline")
    label_lines.append("ConvNeXt-T")
    label = "\n".join(label_lines)

    color = [0.66, 0.66, 0.66]

    axs[0].plot(epoch_num_list, train_loss_list, label=label, color=color, marker=".", linestyle="--")
    axs[1].plot(epoch_num_list, val_loss_list, label=label, color=color, marker=".", linestyle="--")

    # ConvNeXt-T + Fusion Baseline (0) S1 + S2

    exp_data_1 = exp_data_all["ret_train_old_smpl"]["convnext_t_s1"]["exp_000"]
    exp_data_2 = exp_data_all["ret_train_old_smpl"]["convnext_t_s2"]["exp_000"]

    train_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["train_mean_loss_list"]]
    val_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["val_mean_loss_list"]]

    train_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["train_mean_loss_list"]]
    val_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["val_mean_loss_list"]]

    train_loss_list = train_loss_list_1 + train_loss_list_2
    val_loss_list = val_loss_list_1 + val_loss_list_2

    epoch_num_list = [idx + 1 for idx in range(len(train_loss_list_1))] + [idx + 31 for idx in range(len(train_loss_list_2))]

    label_lines = []
    label_lines.append("Stage 1+2 Baseline")
    label_lines.append("ConvNeXt-T + Fusion Head (BottomUp)")
    label = "\n".join(label_lines)

    color = [0.33, 0.33, 0.33]

    axs[0].plot(epoch_num_list, train_loss_list, label=label, color=color, marker=".", linestyle="--")
    axs[1].plot(epoch_num_list, val_loss_list, label=label, color=color, marker=".", linestyle="--")

    # ConvNeXt-T + Fusion Baseline (6) S1

    exp_data_1 = exp_data_all["ret_train_old_smpl"]["convnext_t_s1"]["exp_006"]
    exp_data_2 = exp_data_all["ret_train_old_smpl"]["convnext_t_s2"]["exp_006"]

    train_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["train_mean_loss_list"]]
    val_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["val_mean_loss_list"]]

    train_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["train_mean_loss_list"]]
    val_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["val_mean_loss_list"]]

    train_loss_list = train_loss_list_1 + train_loss_list_2
    val_loss_list = val_loss_list_1 + val_loss_list_2

    epoch_num_list = [idx + 1 for idx in range(len(train_loss_list_1))] + [idx + 31 for idx in range(len(train_loss_list_2))]

    label_lines = []
    label_lines.append("Stage 1+2 Baseline")
    label_lines.append("ConvNeXt-T + Fusion Head (TopDown)")
    label = "\n".join(label_lines)

    color = [0.33, 0.33, 0.33]

    axs[0].plot(epoch_num_list, train_loss_list, label=label, color=color, marker=".", linestyle="--")
    axs[1].plot(epoch_num_list, val_loss_list, label=label, color=color, marker=".", linestyle="--")

    # SwinTV2-T Baseline S1 + S2

    exp_data_1 = exp_data_all["ret_train_old_smpl"]["swint_v2_t_s1"]["exp_014"]
    exp_data_2 = exp_data_all["ret_train_old_smpl"]["swint_v2_t_s2"]["run_002"]

    train_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["train_mean_loss_list"]]
    val_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["val_mean_loss_list"]]

    train_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["train_mean_loss_list"]]
    val_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["val_mean_loss_list"]]

    train_loss_list = train_loss_list_1 + train_loss_list_2
    val_loss_list = val_loss_list_1 + val_loss_list_2

    epoch_num_list = [idx + 1 for idx in range(len(train_loss_list_1))] + [idx + 31 for idx in range(len(train_loss_list_2))]

    label_lines = []
    label_lines.append("Stage 1+2 Baseline")
    label_lines.append("SwinTransformerV2-T")
    label = "\n".join(label_lines)

    color = [0, 0, 0]

    axs[0].plot(epoch_num_list, train_loss_list, label=label, color=color, marker=".", linestyle="--")
    axs[1].plot(epoch_num_list, val_loss_list, label=label, color=color, marker=".", linestyle="--")

    # Experiments from ret_train_old_smpl_2 with GLAM S1 + S2

    for exp_name_1, exp_data_1, exp_name_2, exp_data_2 in zip(exp_name_list_1, exp_data_list_1, exp_name_list_2, exp_data_list_2):

        # Load data

        train_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["train_mean_loss_list"]]
        val_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["val_mean_loss_list"]]

        train_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["train_mean_loss_list"]]
        val_loss_list_2 = [sum(l) for l in exp_data_2["results"]["stage_2"]["val_mean_loss_list"]]

        train_loss_list = train_loss_list_1 + train_loss_list_2
        val_loss_list = val_loss_list_1 + val_loss_list_2

        epoch_num_list = [idx + 1 for idx in range(len(train_loss_list_1))] + [idx + 31 for idx in range(len(train_loss_list_2))]

        finished = exp_data_2["results"]["stage_2"]["finished"]
        base_lr = exp_data_2["settings"]["stage_2"]["optimizer"]["lr"]
        gamma = gamma = exp_data_2["settings"]["stage_2"]["scheduler"]["gamma"]

        head_class = exp_data_2["settings"]["head"]["class"]

        # Title

        title_lines = []    
        title_lines.append("{:s}".format(exp_name))
        if math.isnan(train_loss_list[-1]):
            title_lines[-1] += " | NAN"
        elif not finished:
            title_lines[-1] += " | Unifinished"
        title_lines.append("ConvNeXt-T")
        title_lines.append("{:2s}".format(
            head_class
        ))
        title_lines.append("LR: {:s}".format(np.format_float_scientific(base_lr, min_digits=2, exp_digits=1)))
        title_lines.append("GAM: {:.2f}".format(gamma))

        label = "\n".join(title_lines)

        
        # Plot

        axs[0].plot(epoch_num_list, train_loss_list, label=label, marker=".")
        axs[1].plot(epoch_num_list, val_loss_list, label=label, marker=".")

    # Generic settings

    axs[0].set_yscale("log")
    axs[1].set_yscale("log")

    axs[0].grid()
    axs[1].grid()

    axs[0].set_title("Train loss")
    axs[1].set_title("Val loss")

    #plt.suptitle("Head {:d}".format(head_idx))
    plt.legend(prop={'family': 'monospace', "size": 13}, bbox_to_anchor=(1.30, 1.40))
    plt.show()

# %%
#exp_name_list_1 = ["glam_000_exp_004" for exp_idx in [0, 1, 2, 3, 4, 5, 6]] + ["glam_000_exp_006" for exp_idx in [7]]
exp_name_list_1 = ["glam_000_exp_004" for exp_idx in []] + ["glam_000_exp_006" for exp_idx in [7]]
exp_data_list_1 = [exp_data_all["ret_train_old_smpl_2"]["convnext_t_s1"][key] for key in exp_name_list_1]

#exp_name_list_2 = ["glam_000_exp_{:03d}".format(exp_idx) for exp_idx in [0, 1, 2, 3, 4, 5, 6, 7]]
exp_name_list_2 = ["glam_000_exp_{:03d}".format(exp_idx) for exp_idx in [7]]
exp_data_list_2 = [exp_data_all["ret_train_old_smpl_2"]["convnext_t_s2"][key] for key in exp_name_list_2]

#

plot_losses_2(
    exp_name_list_1,
    exp_name_list_2,
    exp_data_list_1,
    exp_data_list_2
)

# %%
def plot_losses_2_no_baseline(
    exp_name_list,
    exp_data_list,
    head_idx,
    num_epochs=5
):

    fig, axs = plt.subplots(nrows=2, figsize=(20, 12))

    # Experiments from ret_train_old_smpl_2 with GLAM S1 + S2

    exp_data_1 = exp_data_all["ret_train_old_smpl"]["swint_v2_t_s1"]["exp_014"]

    train_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["train_mean_loss_list"]]
    val_loss_list_1 = [sum(l) for l in exp_data_1["results"]["stage_1"]["val_mean_loss_list"]]

    for exp_name, exp_data in zip(exp_name_list, exp_data_list):

        # Load data

        train_loss_list_2 = [sum(l) for l in exp_data["results"]["stage_2"]["train_mean_loss_list"]]
        val_loss_list_2 = [sum(l) for l in exp_data["results"]["stage_2"]["val_mean_loss_list"]]

        train_loss_list_2 = train_loss_list_2[:min(num_epochs, len(train_loss_list_2))]
        val_loss_list_2 = val_loss_list_2[:min(num_epochs, len(val_loss_list_2))]

        train_loss_list = train_loss_list_1 + train_loss_list_2
        val_loss_list = val_loss_list_1 + val_loss_list_2

        epoch_num_list = [idx + 1 for idx in range(len(train_loss_list_1))] + [idx + 31 for idx in range(len(train_loss_list_2))]

        finished = exp_data["results"]["stage_2"]["finished"]
        base_lr = exp_data["settings"]["stage_2"]["optimizer"]["lr"]
        gamma = exp_data["settings"]["stage_2"]["scheduler"]["gamma"]

        head_class = exp_data["settings"]["head"]["class"]

        # Title

        title_lines = []    
        title_lines.append("{:s}".format(exp_name))
        if math.isnan(train_loss_list[-1]):
            title_lines[-1] += " | NAN"
        elif not finished:
            title_lines[-1] += " | Unifinished"
        title_lines.append("ConvNeXt-T")
        title_lines.append("{:2s}".format(
            head_class
        ))
        title_lines.append("LR: {:s}".format(np.format_float_scientific(base_lr, min_digits=2, exp_digits=1)))
        title_lines.append("GAM: {:.2f}".format(gamma))

        label = "\n".join(title_lines)

        
        # Plot

        axs[0].plot(epoch_num_list, train_loss_list, label=label, marker=".")
        axs[1].plot(epoch_num_list, val_loss_list, label=label, marker=".")

    # Generic settings

    axs[0].set_yscale("log")
    axs[1].set_yscale("log")

    axs[0].grid()
    axs[1].grid()

    axs[0].set_title("Train loss")
    axs[1].set_title("Val loss")

    #plt.suptitle("Head {:d}".format(head_idx))
    plt.legend(prop={'family': 'monospace', "size": 13}, bbox_to_anchor=(1.30, 2.00))
    plt.show()

# %%
exp_name_list = ["glam_000_exp_{:03d}".format(exp_idx) for exp_idx in [0, 1, 2, 3, 4, 5, 6]]
exp_data_list = [exp_data_all["ret_train_old_smpl_2"]["convnext_t_s2"][key] for key in exp_name_list]

#

plot_losses_2_no_baseline(
    exp_name_list,
    exp_data_list,
    None,
    num_epochs=30
)
