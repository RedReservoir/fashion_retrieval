# %%
import os
import deep_fashion

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import skimage.io

from torch.utils.data import DataLoader
import torchvision.io
from torchvision.transforms import Resize, Lambda, Compose

import torch

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ---

# %%
capbm_image_transform = Resize(size=(128, 128), antialias=True)
capbm_dataset_dir = os.path.join("..", "fashion_datasets_raw", "DeepFashion", "Category_AttrPred_BM")
capbm_dataset = deep_fashion.CatAttrPredBM(capbm_dataset_dir, capbm_image_transform)

# %%
def show_data_CatAttrPredBM(image, category, attributes):

    image_copy = image

    if type(image) == torch.Tensor:
        image_copy = image_copy.permute(1, 2, 0)

    plt.imshow(image_copy)
    
    title = ""
    title += "Category: {:d}".format(category)
    title += "\n"
    title += "Attr +: "
    for idx, attr in enumerate(attributes):
        if attr == 1: title += "{:d}, ".format(idx)
    title += "\n"
    title += "Attr ?: "
    for idx, attr in enumerate(attributes):
        if attr == 0: title += "{:d}, ".format(idx)

    plt.title(title)

    plt.show()

# %%
for idx in range(30):
    image, category, attributes = capbm_dataset[idx]
    show_data_CatAttrPredBM(image, category, attributes)
