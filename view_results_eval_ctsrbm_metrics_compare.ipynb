# %%
import os
import pathlib

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import src.utils.time
import src.utils.dict
import src.utils.comps
import src.utils.module
import src.utils.json

import src.comps.heads_pyramid_2

# %%
tab20_color_list =\
    [mpl.colormaps["tab20"](x) for x in (np.linspace(0, 1-1/20, 20) + 1/(2*20))[0::2]] +\
    [mpl.colormaps["tab20"](x) for x in (np.linspace(0, 1-1/20, 20) + 1/(2*20))[1::2]]

# %% [markdown]
# ---

# %%
data_df = pd.DataFrame({
    "backbone": pd.Series(dtype="str"),
    "exp_name": pd.Series(dtype="str"),
    "last_val_loss": pd.Series(dtype="float"),
    "avg_train_r_at_10": pd.Series(dtype="float"),
    "avg_val_r_at_10": pd.Series(dtype="float"),
    "avg_test_r_at_10": pd.Series(dtype="float")
})

# %%
# ret_train/resnet_50

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", "ret_train", "resnet_50")
for exp_name in ["test_{:03d}".format(idx) for idx in range(9)]:

    row = {}
    row["exp_name"] = exp_name

    #

    exp_filename = os.path.join(exp_dirname, exp_name, "exp_data_corr.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    row["backbone"] = exp_data["settings"]["backbone"]["class"]
    row["last_val_loss"] = sum(exp_data["results"]["stage_2"]["val_mean_loss_list"][-1])

    #

    metrics_filename = os.path.join(exp_dirname, exp_name, "eval_ctsrbm_metrics__data.json")
    if os.path.exists(metrics_filename):
    
        metrics_data = src.utils.json.load_json_dict(metrics_filename)

        row["avg_train_r_at_10"] = metrics_data["results"]["train"]["avg_r_at_k_dict"]["10"]
        row["avg_val_r_at_10"] = metrics_data["results"]["val"]["avg_r_at_k_dict"]["10"]
        row["avg_test_r_at_10"] = metrics_data["results"]["test"]["avg_r_at_k_dict"]["10"]
        
    #

    data_df.loc[len(data_df)] = row

# %%
# ret_train/convnext_t

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", "ret_train", "convnext_t")
for exp_name in ["test_{:03d}".format(idx) for idx in range(9)]:

    row = {}
    row["exp_name"] = exp_name

    #

    exp_filename = os.path.join(exp_dirname, exp_name, "exp_data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    row["backbone"] = exp_data["settings"]["backbone"]["class"]
    row["last_val_loss"] = sum(exp_data["results"]["stage_2"]["val_mean_loss_list"][-1])

    #

    metrics_filename = os.path.join(exp_dirname, exp_name, "eval_ctsrbm_metrics__data.json")
    if os.path.exists(metrics_filename):
    
        metrics_data = src.utils.json.load_json_dict(metrics_filename)

        row["avg_train_r_at_10"] = metrics_data["results"]["train"]["avg_r_at_k_dict"]["10"]
        row["avg_val_r_at_10"] = metrics_data["results"]["val"]["avg_r_at_k_dict"]["10"]
        row["avg_test_r_at_10"] = metrics_data["results"]["test"]["avg_r_at_k_dict"]["10"]
        
    #

    data_df.loc[len(data_df)] = row

# %%
# ret_train_DDP_2/swint_v2_t_s2

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", "ret_train_DDP_2", "swint_v2_t_s2")
for exp_name in ["run_{:03d}".format(idx) for idx in range(12)]:

    row = {}
    row["exp_name"] = exp_name

    #

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_2__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    row["backbone"] = exp_data["settings"]["backbone"]["class"]
    row["last_val_loss"] = sum(exp_data["results"]["stage_2"]["val_mean_loss_list"][-1])

    #

    metrics_filename = os.path.join(exp_dirname, exp_name, "eval_ctsrbm_metrics__data.json")
    if os.path.exists(metrics_filename):
    
        metrics_data = src.utils.json.load_json_dict(metrics_filename)

        row["avg_train_r_at_10"] = metrics_data["results"]["train"]["avg_r_at_k_dict"]["10"]
        row["avg_val_r_at_10"] = metrics_data["results"]["val"]["avg_r_at_k_dict"]["10"]
        row["avg_test_r_at_10"] = metrics_data["results"]["test"]["avg_r_at_k_dict"]["10"]

    #

    data_df.loc[len(data_df)] = row

# %%
# ret_train_pyr_2/convnext_t_s2

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", "ret_train_pyr_2", "convnext_t_s2")
for exp_name in ["exp_{:03d}".format(idx) for idx in [3, 6]]:

    row = {}
    row["exp_name"] = exp_name

    #

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_2__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    row["backbone"] = exp_data["settings"]["backbone"]["class"]
    row["last_val_loss"] = sum(exp_data["results"]["stage_2"]["val_mean_loss_list"][-1])

    #

    metrics_filename = os.path.join(exp_dirname, exp_name, "eval_ctsrbm_metrics__data.json")
    if os.path.exists(metrics_filename):
    
        metrics_data = src.utils.json.load_json_dict(metrics_filename)

        row["avg_train_r_at_10"] = metrics_data["results"]["train"]["avg_r_at_k_dict"]["10"]
        row["avg_val_r_at_10"] = metrics_data["results"]["val"]["avg_r_at_k_dict"]["10"]
        row["avg_test_r_at_10"] = metrics_data["results"]["test"]["avg_r_at_k_dict"]["10"]

    #

    data_df.loc[len(data_df)] = row

# %%
# ret_train_old_smpl/convnext_t_s2

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", "ret_train_old_smpl", "convnext_t_s2")
for exp_name in ["exp_{:03d}".format(idx) for idx in [0, 6]]:

    row = {}
    row["exp_name"] = exp_name

    #

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_2__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    row["backbone"] = exp_data["settings"]["backbone"]["class"] + " (Old Neg. Smpl.)"
    row["last_val_loss"] = sum(exp_data["results"]["stage_2"]["val_mean_loss_list"][-1])

    #

    metrics_filename = os.path.join(exp_dirname, exp_name, "eval_ctsrbm_metrics__data.json")
    if os.path.exists(metrics_filename):
    
        metrics_data = src.utils.json.load_json_dict(metrics_filename)

        row["avg_train_r_at_10"] = metrics_data["results"]["train"]["avg_r_at_k_dict"]["10"]
        row["avg_val_r_at_10"] = metrics_data["results"]["val"]["avg_r_at_k_dict"]["10"]
        row["avg_test_r_at_10"] = metrics_data["results"]["test"]["avg_r_at_k_dict"]["10"]

    #

    data_df.loc[len(data_df)] = row

# %%
# ret_train_old_smpl/swint_v2_t_s2

exp_dirname = os.path.join(pathlib.Path.home(), "data", "fashion_retrieval", "ret_train_old_smpl", "swint_v2_t_s2")
for exp_name in ["run_{:03d}".format(idx) for idx in [2]]:

    row = {}
    row["exp_name"] = exp_name

    #

    exp_filename = os.path.join(exp_dirname, exp_name, "train_ret_DDP_stage_2__data.json")
    exp_data = src.utils.json.load_json_dict(exp_filename)

    row["backbone"] = exp_data["settings"]["backbone"]["class"] + " (Old Neg. Smpl.)"
    row["last_val_loss"] = sum(exp_data["results"]["stage_2"]["val_mean_loss_list"][-1])

    #

    metrics_filename = os.path.join(exp_dirname, exp_name, "eval_ctsrbm_metrics__data.json")
    if os.path.exists(metrics_filename):
    
        metrics_data = src.utils.json.load_json_dict(metrics_filename)

        row["avg_train_r_at_10"] = metrics_data["results"]["train"]["avg_r_at_k_dict"]["10"]
        row["avg_val_r_at_10"] = metrics_data["results"]["val"]["avg_r_at_k_dict"]["10"]
        row["avg_test_r_at_10"] = metrics_data["results"]["test"]["avg_r_at_k_dict"]["10"]

    #

    data_df.loc[len(data_df)] = row

# %%
data_df
# Out:
#                                           backbone  exp_name  last_val_loss  \
# 0                                 ResNet50Backbone  test_000       0.001367
# 1                                 ResNet50Backbone  test_001       0.001610
# 2                                 ResNet50Backbone  test_002       0.002216
# 3                                 ResNet50Backbone  test_003       0.002515
# 4                                 ResNet50Backbone  test_004       0.002783
# 5                                 ResNet50Backbone  test_005       0.003459
# 6                                 ResNet50Backbone  test_006       0.007115
# 7                                 ResNet50Backbone  test_007       0.005023
# 8                                 ResNet50Backbone  test_008       0.005601
# 9                             ConvNeXtTinyBackbone  test_000       0.059938
# 10                            ConvNeXtTinyBackbone  test_001       0.088033
# 11                            ConvNeXtTinyBackbone  test_002       0.061793
# 12                            ConvNeXtTinyBackbone  test_003       0.073057
# 13                            ConvNeXtTinyBackbone  test_004       0.068825
# 14                            ConvNeXtTinyBackbone  test_005       0.102461
# 15                            ConvNeXtTinyBackbone  test_006       0.066156
# 16                            ConvNeXtTinyBackbone  test_007       0.083384
# 17                            ConvNeXtTinyBackbone  test_008       0.082099
# 18                   SwinTransformerV2TinyBackbone   run_000       0.123514
# 19                   SwinTransformerV2TinyBackbone   run_001       0.047429
# 20                   SwinTransformerV2TinyBackbone   run_002       0.013073
# 21                   SwinTransformerV2TinyBackbone   run_003       0.014477
# 22                   SwinTransformerV2TinyBackbone   run_004       0.015260
# 23                   SwinTransformerV2TinyBackbone   run_005       0.016757
# 24                   SwinTransformerV2TinyBackbone   run_006       0.019394
# 25                   SwinTransformerV2TinyBackbone   run_007       0.020539
# 26                   SwinTransformerV2TinyBackbone   run_008       0.015635
# 27                   SwinTransformerV2TinyBackbone   run_009       0.015426
# 28                   SwinTransformerV2TinyBackbone   run_010       0.015310
# 29                   SwinTransformerV2TinyBackbone   run_011       0.014380
# 30                     ConvNeXtTinyPyramidBackbone   exp_003       0.013830
# 31                     ConvNeXtTinyPyramidBackbone   exp_006       0.013484
# 32    ConvNeXtTinyPyramidBackbone (Old Neg. Smpl.)   exp_000       0.046105
# 33    ConvNeXtTinyPyramidBackbone (Old Neg. Smpl.)   exp_006       0.046287
# 34  SwinTransformerV2TinyBackbone (Old Neg. Smpl.)   run_002       0.033926
#
#     avg_train_r_at_10  avg_val_r_at_10  avg_test_r_at_10
# 0            0.092963         0.113005          0.113512
# 1            0.080858         0.103989          0.102973
# 2            0.074515         0.095596          0.095451
# 3            0.101367         0.121667          0.122187
# 4            0.085285         0.105745          0.107343
# 5            0.082022         0.102327          0.105822
# 6            0.111395         0.138329          0.141448
# 7            0.088110         0.112440          0.112181
# 8            0.089028         0.111069          0.111467
# 9            0.146044         0.185281          0.186671
# 10           0.124151         0.156609          0.160845
# 11           0.159314         0.193387          0.198058
# 12           0.141500         0.173407          0.176368
# 13           0.134393         0.172071          0.174219
# 14           0.113155         0.145366          0.146978
# 15           0.151040         0.186136          0.188529
# 16           0.133585         0.164949          0.168801
# 17           0.126592         0.162248          0.164739
# 18           0.004421         0.006223          0.006797
# 19           0.030107         0.039790          0.041324
# 20           0.149659         0.182388          0.185130
# 21           0.124923         0.156733          0.159092
# 22           0.112612         0.143306          0.143416
# 23           0.101745         0.128493          0.131459
# 24           0.090764         0.114318          0.117489
# 25           0.085498         0.107373          0.112087
# 26                NaN              NaN               NaN
# 27                NaN              NaN               NaN
# 28                NaN              NaN               NaN
# 29                NaN              NaN               NaN
# 30           0.108170         0.137465          0.138740
# 31           0.110034         0.138264          0.140181
# 32           0.188251         0.227393          0.230145
# 33           0.189950         0.227768          0.230842
# 34           0.234992         0.278996          0.283247

# %% [markdown]
# ---

# %%
metric_name = "avg_val_r_at_10"

ord_df = data_df.copy()
ord_df = ord_df[~(pd.isna(ord_df[metric_name]))]
ord_df = ord_df[ord_df["backbone"] != "ConvNeXtTinyPyramidBackbone"]
ord_df = ord_df.sort_values(metric_name, ascending=True)
ord_df = ord_df.reset_index(drop=True)

###

plt.figure(figsize=(24, 6))

###

for backbone in ord_df["backbone"].unique():

    ord_df_filt = ord_df[ord_df["backbone"] == backbone].copy()

    if backbone == "ResNet50Backbone": backbone_color = tab20_color_list[0]
    if backbone == "ConvNeXtTinyBackbone": backbone_color = tab20_color_list[1]
    if backbone == "SwinTransformerV2TinyBackbone": backbone_color = tab20_color_list[2]
    if backbone == "SwinTransformerV2TinyBackbone": backbone_color = tab20_color_list[3]
    if backbone == "ConvNeXtTinyPyramidBackbone (Old Neg. Smpl.)": backbone_color= tab20_color_list[4]
    if backbone == "ConvNeXtTinyPyramidBackbone (Old Neg. Smpl.)": backbone_color= tab20_color_list[5]

    plt.bar(np.asarray(ord_df_filt.index), ord_df_filt[metric_name], color=backbone_color, alpha=1, label=backbone)

plt.legend()

###

plt.xticks([])
plt.title(metric_name)

###

text_height = - plt.ylim()[1] * 0.060

plt.text(-1, text_height, "Run", ha="center")

for backbone in ord_df["backbone"].unique():

    ord_df_filt = ord_df[ord_df["backbone"] == backbone]

    for idx in ord_df_filt.index:
        text = "{:s}".format(
            ord_df_filt.at[idx, "exp_name"][-3:]
        )
        plt.text(idx, text_height, text, ha="center", family="monospace")
        
###

plt.grid(True)
plt.show()

# %%
metric_train_name = "avg_train_r_at_10"
metric_val_name = "avg_val_r_at_10"
metric_test_name = "avg_test_r_at_10"

ord_df = data_df.copy()
ord_df = ord_df[~(pd.isna(ord_df[metric_test_name]))]
ord_df = ord_df.sort_values(metric_test_name, ascending=True)
ord_df = ord_df.reset_index(drop=True)

###

plt.figure(figsize=(24, 6))

###

bar_width = 0.8

for backbone in [
    "ResNet50Backbone",
    "ConvNeXtTinyBackbone",
    "ConvNeXtTinyPyramidBackbone",
    "SwinTransformerV2TinyBackbone",
    "ConvNeXtTinyPyramidBackbone (Old Neg. Smpl.)",
    "SwinTransformerV2TinyBackbone (Old Neg. Smpl.)",
]:

    ord_df_filt = ord_df[ord_df["backbone"] == backbone].copy()

    if backbone == "ResNet50Backbone": backbone_color = tab20_color_list[0]
    if backbone == "ConvNeXtTinyBackbone": backbone_color = tab20_color_list[1]
    if backbone == "ConvNeXtTinyPyramidBackbone": backbone_color = tab20_color_list[2]
    if backbone == "SwinTransformerV2TinyBackbone": backbone_color = tab20_color_list[3]
    if backbone == "ConvNeXtTinyPyramidBackbone (Old Neg. Smpl.)": backbone_color= tab20_color_list[4]
    if backbone == "SwinTransformerV2TinyBackbone (Old Neg. Smpl.)": backbone_color= tab20_color_list[5]
    
    plt.bar(np.asarray(ord_df_filt.index) - bar_width/3, ord_df_filt[metric_train_name], color=backbone_color, alpha=0.5, width=bar_width/3)
    plt.bar(np.asarray(ord_df_filt.index), ord_df_filt[metric_val_name], color=backbone_color, alpha=0.6, width=bar_width/3)
    plt.bar(np.asarray(ord_df_filt.index) + bar_width/3, ord_df_filt[metric_test_name], color=backbone_color, alpha=1, width=bar_width/3, label=backbone)

plt.legend()

###

plt.xticks([])
plt.title("Average Train/Val/Test Recall @ 10")

###

text_height = - plt.ylim()[1] * 0.060

plt.text(-1, text_height, "Run", ha="center")

for backbone in ord_df["backbone"].unique():

    ord_df_filt = ord_df[ord_df["backbone"] == backbone]

    for idx in ord_df_filt.index:
        text = "{:s}".format(
            ord_df_filt.at[idx, "exp_name"][-3:]
        )
        plt.text(idx, text_height, text, ha="center", family="monospace")
        
###

plt.grid(True)
plt.show()
