# %%
import os
import deep_fashion

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import skimage.io

from torch.utils.data import DataLoader
import torchvision.io
from torchvision.transforms import Resize, Lambda, Compose

import torch

from tqdm.notebook import trange, tqdm

# %% [markdown]
# ---

# %%
ctsrbm_image_transform = Compose([
    Lambda(lambda img: img.repeat(3, 1, 1) if img.size(dim=0) == 1 else img),
    Resize(size=(128, 128), antialias=True)
])
ctsrbm_dataset_dir = os.path.join("..", "fashion_datasets_raw", "DeepFashion", "ConsumerToShop_Retrieval_BM")
ctsrbm_dataset = deep_fashion.ConsToShopClothRetrBM(ctsrbm_dataset_dir, ctsrbm_image_transform)

# %%
def show_data_ConsToShopClothRetrBM(image_1, image_2, image_3, attributes):

    fig, axs = plt.subplots(ncols=3)

    axs[0].imshow(image_1.permute(1, 2, 0))
    axs[1].imshow(image_2.permute(1, 2, 0))
    axs[2].imshow(image_3.permute(1, 2, 0))
    
    title = ""
    title += "Attr +: "
    for idx, attr in enumerate(attributes):
        if attr == 1: title += "{:d}, ".format(idx)
    title += "\n"
    title += "Attr ?: "
    for idx, attr in enumerate(attributes):
        if attr == 0: title += "{:d}, ".format(idx)

    plt.title(title)

    plt.show()

# %%
for idx in range(30):
    image_1, image_2, image_3, attributes = ctsrbm_dataset[idx]
    show_data_ConsToShopClothRetrBM(image_1, image_2, image_3, attributes)
