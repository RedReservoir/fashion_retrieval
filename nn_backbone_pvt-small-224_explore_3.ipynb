# %%
import torch
import torchvision

from torchvision import models
import transformers
from transformers import PvtModel, AutoImageProcessor

from fir.datasets import deep_fashion_ctsrbm

import os
import pathlib

import numpy as np

from datasets import load_dataset

from tqdm.notebook import tqdm

import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image
import requests

url = "http://assets.myntassets.com/v1/images/style/properties/7a5b82d1372a7a5c6de67ae7a314fd91_images.jpg"
im = Image.open(requests.get(url, stream=True).raw)
im_2 = torchvision.transforms.ToTensor()(im)

# %%
im_2.shape
# Out:
# torch.Size([3, 2400, 1800])

# %%
im.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 im.shape
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'

# %%
dataset = load_dataset("beans", split="train").cast_column("image", Image(decode=False))
dataset[0]["image"]
# Out:
# Downloading builder script:   0%|          | 0.00/3.61k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.24k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/4.75k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/144M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/18.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/17.7M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1034 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/133 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/128 [00:00<?, ? examples/s]
# {'bytes': None,
#  'path': '/home-net/gortega/.cache/huggingface/datasets/downloads/extracted/f610d1711e0269a8fee838327126d9991911d70b053bbc88f981f3a823a07ff5/train/angular_leaf_spot/angular_leaf_spot_train.0.jpg'}

# %%
def show_img(idx):

    image, item_id = ctsrbm_dataset[idx]

    image_copy = image

    if type(image) == torch.Tensor:
        image_copy = image_copy.permute(1, 2, 0)

    vmax = image_copy.max().item()
    vmin = image_copy.min().item()

    image_copy = (image_copy - vmin) / (vmax - vmin)

    plt.imshow(image_copy)
    
    title_lines = []
    title_lines.append("Image ID: {:d}".format(idx))
    title_lines.append("Item ID: {:d}".format(item_id))
    title_lines.append("Size: " + str(image_copy.size()))
    plt.title("\n".join(title_lines))

    plt.show()

# %% [markdown]
# ---

# %%
path_to_img = os.path.join(
    pathlib.Path.home(),
    "data",
    "DeepFashion",
    "Consumer-to-shop Clothes Retrieval Benchmark",
    "img",
    "CLOTHING",
    "Blouse",
    "id_00004848",
    "comsumer_01.jpg"
)

img_original = torchvision.io.read_image(path_to_img)

# %%
print(img_original.shape)
# Out:
# torch.Size([3, 300, 169])

# %%
ctsrbm_image_transform = AutoImageProcessor.from_pretrained("Zetatech/pvt-small-224")
#ctsrbm_image_transform.size["height"] = 224
#ctsrbm_image_transform.size["width"] = 224
ctsrbm_image_transform_corr = lambda t: torch.from_numpy(ctsrbm_image_transform(t).pixel_values[0])

# %%
ctsrbm_image_transform
# Out:
# PvtImageProcessor {
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.485,
#     0.456,
#     0.406
#   ],
#   "image_processor_type": "PvtImageProcessor",
#   "image_std": [
#     0.229,
#     0.224,
#     0.225
#   ],
#   "resample": 2,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "height": 224,
#     "width": 224
#   }
# }

# %%
img_transformed = ctsrbm_image_transform_corr(img_original)

# %%
img_transformed.shape
# Out:
# torch.Size([3, 224, 224])

# %%
img_copy = torch.clone(img_transformed)
img_copy = img_copy.permute(1, 2, 0)

vmax = img_copy.max().item()
vmin = img_copy.min().item()

img_copy = (img_copy - vmin) / (vmax - vmin)

plt.imshow(img_copy)
plt.title(str(img_copy.shape))
plt.axis("off")
plt.show()

# %% [markdown]
# ---

# %%
model = PvtModel.from_pretrained("Zetatech/pvt-small-224")

# %%
ctsrbm_image_transform = AutoImageProcessor.from_pretrained("Zetatech/pvt-small-224")
ctsrbm_image_transform.size["height"] = 448
ctsrbm_image_transform.size["width"] = 448
ctsrbm_image_transform_corr = lambda t: torch.from_numpy(ctsrbm_image_transform(t).pixel_values[0])
ctsrbm_dataset_dir = os.path.join(pathlib.Path.home(), "data", "DeepFashion", "Consumer-to-shop Clothes Retrieval Benchmark")
ctsrbm_dataset = deep_fashion_ctsrbm.ConsToShopClothRetrBmkImageLoader(ctsrbm_dataset_dir, ctsrbm_image_transform_corr)

# %%
ctsrbm_image_transform
# Out:
# PvtImageProcessor {
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.485,
#     0.456,
#     0.406
#   ],
#   "image_processor_type": "PvtImageProcessor",
#   "image_std": [
#     0.229,
#     0.224,
#     0.225
#   ],
#   "resample": 2,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "height": 448,
#     "width": 448
#   }
# }

# %%
input = ctsrbm_dataset[0]

img_tensor = input[0]
item_id = input[1]

# %%
print(img_tensor.shape)
# Out:
# torch.Size([3, 448, 448])

# %%
item_id
# Out:
# 24444

# %%
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output
    return hook

model.encoder.block[0].register_forward_hook(get_activation('encoder.block[0]'))
model.encoder.block[1].register_forward_hook(get_activation('encoder.block[1]'))
model.encoder.block[2].register_forward_hook(get_activation('encoder.block[2]'))
model.encoder.block[3].register_forward_hook(get_activation('encoder.block[3]'))
model.encoder.layer_norm.register_forward_hook(get_activation('encoder.layer_norm'))
model.encoder.register_forward_hook(get_activation('encoder'))

# %%
input = ctsrbm_dataset[0][0][None, :, :224, :224]
output = model(input)
# Out:
# HOLA
#
# batch_size: 1
# num_channels: 3
# height: 224
# width: 224
#
# height: 56
# width: 56
#
# embeddings.shape: torch.Size([1, 3136, 64])
#
# self.cls_token is None
#
#   CALL: interpolate_pos_encoding
#   embeddings.shape: torch.Size([1, 3136, 64])
#   height: 56
#   width: 56
#
#   num_patches: 3136
#   self.config.image_size: 224
#   self.config.image_size ** 2: 50176
#
#   embeddings.shape: torch.Size([1, 3136, 64])
#   embeddings.shape: torch.Size([1, 64, 56, 56])
#   interpolated_embeddings.shape: torch.Size([1, 64, 56, 56])
#   interpolated_embeddings.shape: torch.Size([1, 3136, 64])
#
# self.position_embeddings.shape: torch.Size([1, 3136, 64])
# position_embeddings.shape: torch.Size([1, 3136, 64])
#
#
# ---
#
# HOLA
#
# batch_size: 1
# num_channels: 64
# height: 56
# width: 56
#
# height: 28
# width: 28
#
# embeddings.shape: torch.Size([1, 784, 128])
#
# self.cls_token is None
#
#   CALL: interpolate_pos_encoding
#   embeddings.shape: torch.Size([1, 784, 128])
#   height: 28
#   width: 28
#
#   num_patches: 784
#   self.config.image_size: 224
#   self.config.image_size ** 2: 50176
#
#   embeddings.shape: torch.Size([1, 784, 128])
#   embeddings.shape: torch.Size([1, 128, 28, 28])
#   interpolated_embeddings.shape: torch.Size([1, 128, 28, 28])
#   interpolated_embeddings.shape: torch.Size([1, 784, 128])
#
# self.position_embeddings.shape: torch.Size([1, 784, 128])
# position_embeddings.shape: torch.Size([1, 784, 128])
#
#
# ---
#
# HOLA
#
# batch_size: 1
# num_channels: 128
# height: 28
# width: 28
#
# height: 14
# width: 14
#
# embeddings.shape: torch.Size([1, 196, 320])
#
# self.cls_token is None
#
#   CALL: interpolate_pos_encoding
#   embeddings.shape: torch.Size([1, 196, 320])
#   height: 14
#   width: 14
#
#   num_patches: 196
#   self.config.image_size: 224
#   self.config.image_size ** 2: 50176
#
#   embeddings.shape: torch.Size([1, 196, 320])
#   embeddings.shape: torch.Size([1, 320, 14, 14])
#   interpolated_embeddings.shape: torch.Size([1, 320, 14, 14])
#   interpolated_embeddings.shape: torch.Size([1, 196, 320])
#
# self.position_embeddings.shape: torch.Size([1, 196, 320])
# position_embeddings.shape: torch.Size([1, 196, 320])
#
#
# ---
#
# HOLA
#
# batch_size: 1
# num_channels: 320
# height: 14
# width: 14
#
# height: 7
# width: 7
#
# embeddings.shape: torch.Size([1, 49, 512])
#
# self.cls_token is not None
#
#   CALL: interpolate_pos_encoding
#   embeddings.shape: torch.Size([1, 49, 512])
#   height: 7
#   width: 7
#
#   num_patches: 49
#   self.config.image_size: 224
#   self.config.image_size ** 2: 50176
#
#   embeddings.shape: torch.Size([1, 49, 512])
#   embeddings.shape: torch.Size([1, 512, 7, 7])
#   interpolated_embeddings.shape: torch.Size([1, 512, 7, 7])
#   interpolated_embeddings.shape: torch.Size([1, 49, 512])
#
# self.position_embeddings.shape: torch.Size([1, 50, 512])
# position_embeddings.shape: torch.Size([1, 50, 512])
#
# ---

# %%
input = ctsrbm_dataset[0][0][None, :, :448, :448]
output = model(input)
# Out:
# HOLA
#
# batch_size: 1
# num_channels: 3
# height: 448
# width: 448
#
# height: 112
# width: 112
#
# embeddings.shape: torch.Size([1, 12544, 64])
#
# self.cls_token is None
#
#   CALL: interpolate_pos_encoding
#   embeddings.shape: torch.Size([1, 3136, 64])
#   height: 112
#   width: 112
#
#   num_patches: 12544
#   self.config.image_size: 224
#   self.config.image_size ** 2: 50176
#
#   embeddings.shape: torch.Size([1, 3136, 64])
#   embeddings.shape: torch.Size([1, 16, 112, 112])
#   interpolated_embeddings.shape: torch.Size([1, 16, 112, 112])
#   interpolated_embeddings.shape: torch.Size([1, 12544, 16])
#
# self.position_embeddings.shape: torch.Size([1, 3136, 64])
# position_embeddings.shape: torch.Size([1, 12544, 16])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 2
#       1 input = ctsrbm_dataset[0][0][None, :, :448, :448]
# ----> 2 output = model(input)
#
# File ~/fashion_retrieval/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/fashion_retrieval/.venv/lib/python3.8/site-packages/transformers/models/pvt/modeling_pvt.py:608, in PvtModel.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict)
#     603 output_hidden_states = (
#     604     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#     605 )
#     606 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 608 encoder_outputs = self.encoder(
#     609     pixel_values=pixel_values,
#     610     output_attentions=output_attentions,
#     611     output_hidden_states=output_hidden_states,
#     612     return_dict=return_dict,
#     613 )
#     614 sequence_output = encoder_outputs[0]
#     616 if not return_dict:
#
# File ~/fashion_retrieval/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1538, in Module._call_impl(self, *args, **kwargs)
#    1535     bw_hook = hooks.BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1536     args = bw_hook.setup_input_hook(args)
# -> 1538 result = forward_call(*args, **kwargs)
#    1539 if _global_forward_hooks or self._forward_hooks:
#    1540     for hook_id, hook in (
#    1541         *_global_forward_hooks.items(),
#    1542         *self._forward_hooks.items(),
#    1543     ):
#
# File ~/fashion_retrieval/.venv/lib/python3.8/site-packages/transformers/models/pvt/modeling_pvt.py:475, in PvtEncoder.forward(self, pixel_values, output_attentions, output_hidden_states, return_dict)
#     472 hidden_states = pixel_values
#     473 for idx, (embedding_layer, block_layer) in enumerate(zip(self.patch_embeddings, self.block)):
#     474     # first, obtain patch embeddings
# --> 475     hidden_states, height, width = embedding_layer(hidden_states)
#     476     # second, send embeddings through blocks
#     477     for block in block_layer:
#
# File ~/fashion_retrieval/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/fashion_retrieval/.venv/lib/python3.8/site-packages/transformers/models/pvt/modeling_pvt.py:191, in PvtPatchEmbeddings.forward(self, pixel_values)
#     189     print("position_embeddings.shape:", position_embeddings.shape) # DEBUG
#     190     print() # DEBUG
# --> 191 embeddings = self.dropout(embeddings + position_embeddings)
#     193 print() # DEBUG
#     194 print("---") # DEBUG
#
# RuntimeError: The size of tensor a (64) must match the size of tensor b (16) at non-singleton dimension 2
