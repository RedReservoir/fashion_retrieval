# %%
import os
import utils
import random
import sys

# %% [markdown]
# ---

# %%
for x in (x for x in range(10) if x % 5 != 0):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
item_id_to_image_dir_dict = {}

for root, dirs, files in os.walk("../fashion_datasets_raw/DeepFashion/ConsumerToShop_Retrieval_BM/img", topdown=False):
    for name in dirs:

        img_dir = os.path.join(*(root.split(os.sep)[-2:]))
        item_id = name

        item_id_to_image_dir_dict[item_id] = img_dir

# %%
for key, value in item_id_to_image_dir_dict.items():
    print(key, value)
# Out:
# id_00008348 TOPS/T_Shirt
# id_00002918 TOPS/T_Shirt
# id_00024963 TOPS/T_Shirt
# id_00005655 TOPS/T_Shirt
# id_00010513 TOPS/T_Shirt
# id_00023590 TOPS/T_Shirt
# id_00029240 TOPS/T_Shirt
# id_00006156 TOPS/T_Shirt
# id_00023890 TOPS/T_Shirt
# id_00015492 TOPS/T_Shirt
# id_00015335 TOPS/T_Shirt
# id_00028802 TOPS/T_Shirt
# id_00009747 TOPS/T_Shirt
# id_00016153 TOPS/T_Shirt
# id_00014541 TOPS/T_Shirt
# id_00016586 TOPS/T_Shirt
# id_00004642 TOPS/T_Shirt
# id_00011769 TOPS/T_Shirt
# id_00014322 TOPS/T_Shirt
# id_00010210 TOPS/T_Shirt
# id_00027827 TOPS/T_Shirt
# id_00011145 TOPS/T_Shirt
# id_00001370 TOPS/T_Shirt
# id_00005540 TOPS/T_Shirt
# id_00011565 TOPS/T_Shirt
# id_00010415 TOPS/T_Shirt
# id_00012924 TOPS/T_Shirt
# id_00007615 TOPS/T_Shirt
# id_00008034 TOPS/T_Shirt
# id_00028952 TOPS/T_Shirt
# id_00008742 TOPS/T_Shirt
# id_00006290 TOPS/T_Shirt
# id_00013281 TOPS/T_Shirt
# id_00019309 TOPS/T_Shirt
# id_00018067 TOPS/T_Shirt
# id_00024383 TOPS/T_Shirt
# id_00029001 TOPS/T_Shirt
# ...

# %%
utils.sprint_fancy_num_bytes(utils.get_num_bytes(item_id_to_image_dir_dict))
# Out:
# '5.25MB'

# %%
os.listdir("../fashion_datasets_raw/DeepFashion/ConsumerToShop_Retrieval_BM/img")
# Out:
# ['TOPS', 'TROUSERS', 'CLOTHING', 'DRESSES']

# %%
plt.plot(range(1, len(train_loss) + 1), train_loss, label="train")
plt.plot(range(1, len(val_losses) + 1), val_losses, label="val")

plt.title("Loss")
plt.legend()
plt.grid()

plt.show()
